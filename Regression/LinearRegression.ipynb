# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
import math

# %%
(data, target) = load_boston(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.20, random_state=42)

# %%
X_train = [i[0] for i in X_train]

# %%
X_train = np.array(X_train)

# %%
X_test = [i[0] for i in X_test]

# %%
X_test = np.array(X_test)

# %%
def cal_error(y1,y):
    s = 0
    for i in range(len(y)):
        s = s+ (y[i]-y1[i])**2
    s = s/len(y)
    s = math.sqrt(s)
    return s

# %%
a = 0.01
epochs = 1000
w = 0.1 #random value
b = 0.1 #random value
k = 0
while True:
    y1 = []
    for i in range(len(X_train)):
        y1.append(X_train[i]*w+b)
    errory = cal_error(y1,y_train)
    
    w = w-a* sum((y1[i]-y_train[i])*X_train[i] for i in range(len(X_train)))/len(X_train)
    b = b-a* sum((y1[i]-y_train[i]) for i in range(len(X_train)))/len(X_train)
    if(k%100==0):
        print(errory)
    if(errory<0.01):
        break
    k+=1
# Out:
# 24.347887751307198
# 12.793199654224757
# 9.503511260113816
# 8.785558019848377
# 8.650746964865078
# 8.626391279499796
# 8.622023957998726
# 8.621241903466093
# 8.621101895592187
# 8.621076831682466
# 8.62107234483029
# 8.621071541611062
# 8.621071397821854
# 8.621071372081259
# 8.621071367473276
# 8.62107136664838
# 8.621071366500704
# 8.621071366474268
# 8.621071366469538
# 8.621071366468689
# 8.621071366468536
# 8.621071366468511
# 8.62107136646851
# 8.621071366468502
# 8.621071366468506
# 8.621071366468504
# 8.62107136646851
# 8.621071366468502
# 8.621071366468508
# 8.621071366468506
# 8.621071366468504
# 8.621071366468504
# 8.621071366468506
# 8.621071366468508
# 8.621071366468508
# 8.621071366468506
# 8.621071366468506
# 8.62107136646851
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# 8.6210713664685
# ...

# %%
b
# Out:
# 24.238981774011062

# %%
X = 1000
print(w*X + b)
# Out:
# -375.42777095331536
